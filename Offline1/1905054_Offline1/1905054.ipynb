# %% [markdown]
# # Understanding the dataset:

# %%
import pandas as pd # type: ignore

#importing the dataset
dataframe = pd.read_csv("dataset.csv")
dataframe.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
#showing the number of rows and columns
dataframe.shape
# Out:
# (1470, 35)

# %%
#Showing the statistics of the dataset
dataframe.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
#the number of missing values in the dataset
dataframe.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
#the number of duplicate values in the dataset
dataframe.duplicated().sum().item()
# Out:
# 0

# %% [markdown]
# # Data cleaning

# %%
# handling the null values with the mean of the column 
dataframe.fillna(dataframe.select_dtypes(include='number').mean(), inplace=True)
#dataframe.isnull().sum()

# %%
#Droping duplicates, keeping only one copy of data each
dataframe.drop_duplicates(inplace=True)

# %%
#Drop the rows when target is missing

dataframe.dropna(subset=['Attrition'], inplace=True)
dataframe.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# # Creation of input and output features:

# %%
#creating input and output data

features = dataframe.drop('Attrition', axis=1)
labels = dataframe['Attrition']
#input
features
# Out:
#       Age     BusinessTravel  DailyRate              Department  \
# 0      41      Travel_Rarely       1102                   Sales
# 1      49  Travel_Frequently        279  Research & Development
# 2      37      Travel_Rarely       1373  Research & Development
# 3      33  Travel_Frequently       1392  Research & Development
# 4      27      Travel_Rarely        591  Research & Development
# ...   ...                ...        ...                     ...
# 1465   36  Travel_Frequently        884  Research & Development
# 1466   39      Travel_Rarely        613  Research & Development
# 1467   27      Travel_Rarely        155  Research & Development
# 1468   49  Travel_Frequently       1023                   Sales
# 1469   34      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                    1          2  Life Sciences              1
# 1                    8          1  Life Sciences              1
# ...

# %%
#output

labels
# Out:
# 0       Yes
# 1        No
# 2       Yes
# 3        No
# 4        No
#        ...
# 1465     No
# 1466     No
# 1467     No
# 1468     No
# 1469     No
# Name: Attrition, Length: 1470, dtype: object

# %% [markdown]
# # Conversion of features into numeric values:

# %%
#converting the columns into numeric features
from sklearn.preprocessing import LabelEncoder # type: ignore

#label encoding the target
encoder = LabelEncoder()
labels = dataframe['Attrition']
labels = encoder.fit_transform(labels)
labels
# Out:
# array([1, 0, 1, ..., 0, 0, 0])

# %%
# one-hot encoding the features
features = pd.get_dummies(features)
features
# Out:
#       Age  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# 0      41       1102                 1          2              1
# 1      49        279                 8          1              1
# 2      37       1373                 2          2              1
# 3      33       1392                 3          4              1
# 4      27        591                 2          1              1
# ...   ...        ...               ...        ...            ...
# 1465   36        884                23          2              1
# 1466   39        613                 6          1              1
# 1467   27        155                 4          3              1
# 1468   49       1023                 2          3              1
# 1469   34        628                 8          3              1
#
#       EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# 0                  1                        2          94               3
# ...

# %% [markdown]
# # Scaling of the features:

# %%
#Standard scaling 
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
features_std = scaler.fit_transform(features)
features_std
# Out:
# array([[ 0.4463504 ,  0.74252653, -1.01090934, ...,  0.        ,
#         -1.59174553,  1.59174553],
#        [ 1.32236521, -1.2977746 , -0.14714972, ...,  0.        ,
#          0.62824112, -0.62824112],
#        [ 0.008343  ,  1.41436324, -0.88751511, ...,  0.        ,
#         -1.59174553,  1.59174553],
#        ...,
#        [-1.08667552, -1.60518328, -0.64072665, ...,  0.        ,
#         -1.59174553,  1.59174553],
#        [ 1.32236521,  0.54667746, -0.88751511, ...,  0.        ,
#          0.62824112, -0.62824112],
#        [-0.32016256, -0.43256792, -0.14714972, ...,  0.        ,
#          0.62824112, -0.62824112]])

# %%
#MinMax scaling 
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
features_minmax = scaler.fit_transform(features)
features_minmax
# Out:
# array([[0.54761905, 0.71581961, 0.        , ..., 0.        , 0.        ,
#         1.        ],
#        [0.73809524, 0.12670007, 0.25      , ..., 0.        , 1.        ,
#         0.        ],
#        [0.45238095, 0.90980673, 0.03571429, ..., 0.        , 0.        ,
#         1.        ],
#        ...,
#        [0.21428571, 0.03793844, 0.10714286, ..., 0.        , 0.        ,
#         1.        ],
#        [0.73809524, 0.65926986, 0.03571429, ..., 0.        , 1.        ,
#         0.        ],
#        [0.38095238, 0.37652112, 0.25      , ..., 0.        , 1.        ,
#         0.        ]])

# %%
#Using function
from sklearn.preprocessing import StandardScaler, MinMaxScaler

#Defining the scaling function
def scale_features(features, scaler_type='standard'):
    if scaler_type == 'standard':
        scaler = StandardScaler()  
    elif scaler_type == 'minmax':
        scaler = MinMaxScaler()   
    else:
        raise ValueError("Invalid scaler_type. Use 'standard' or 'minmax'.")
    
    # Applying the chosen scaler
    features_scaled = scaler.fit_transform(features)
    
    return features_scaled

# %%
features_show = scale_features(features,'standard')
features_show
# Out:
# array([[ 0.4463504 ,  0.74252653, -1.01090934, ...,  0.        ,
#         -1.59174553,  1.59174553],
#        [ 1.32236521, -1.2977746 , -0.14714972, ...,  0.        ,
#          0.62824112, -0.62824112],
#        [ 0.008343  ,  1.41436324, -0.88751511, ...,  0.        ,
#         -1.59174553,  1.59174553],
#        ...,
#        [-1.08667552, -1.60518328, -0.64072665, ...,  0.        ,
#         -1.59174553,  1.59174553],
#        [ 1.32236521,  0.54667746, -0.88751511, ...,  0.        ,
#          0.62824112, -0.62824112],
#        [-0.32016256, -0.43256792, -0.14714972, ...,  0.        ,
#          0.62824112, -0.62824112]])

# %% [markdown]
# # Correlation Analysis:

# %%
features_df = pd.DataFrame(features_show, columns=features.columns) #scaled featured dataframe
labels_df = pd.DataFrame(labels, columns=['Attrition'])

# %%
#Correlation analysis of features with target
labels_series = labels_df['Attrition']
correlation = features_df.corrwith(labels_series)
correlation
# Out:
# C:\Users\sizan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\sizan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Age                                 -0.159205
# DailyRate                           -0.056652
# DistanceFromHome                     0.077924
# Education                           -0.031373
# EmployeeCount                             NaN
# EmployeeNumber                      -0.010577
# EnvironmentSatisfaction             -0.103369
# HourlyRate                          -0.006846
# JobInvolvement                      -0.130016
# JobLevel                            -0.169105
# ...

# %%
#Selecting top 20 features with the highest correlation with target
correlation_sorted = correlation.abs().sort_values(ascending=False)

top_20_features = correlation_sorted.head(20)
top_20_features
# Out:
# OverTime_Yes                        0.246118
# OverTime_No                         0.246118
# MaritalStatus_Single                0.175419
# TotalWorkingYears                   0.171063
# JobLevel                            0.169105
# YearsInCurrentRole                  0.160545
# MonthlyIncome                       0.159840
# Age                                 0.159205
# JobRole_Sales Representative        0.157234
# YearsWithCurrManager                0.156199
# StockOptionLevel                    0.137145
# YearsAtCompany                      0.134392
# JobInvolvement                      0.130016
# BusinessTravel_Travel_Frequently    0.115143
# JobSatisfaction                     0.103481
# EnvironmentSatisfaction             0.103369
# JobRole_Laboratory Technician       0.098290
# MaritalStatus_Married               0.090984
# JobRole_Research Director           0.088870
# MaritalStatus_Divorced              0.087716
# dtype: float64

# %% [markdown]
# # 1D scatter plot

# %%
import matplotlib.pyplot as plt # type: ignore
import numpy as np

# %%
# Iterating top 20 feature names

top_20_feature_names = top_20_features.index
for feature in top_20_feature_names:
    plt.figure(figsize=(8, 4))
    
    plt.scatter(features_df[feature], labels_series, alpha=0.6)
    
    plt.title(f'Scatter Plot of {feature} vs Attrition')
    plt.xlabel(f'{feature}')
    plt.ylabel('Attrition')
    
    plt.show()
